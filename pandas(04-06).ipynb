# %%
import pandas as pd

# %%
pd.read_csv("products.csv")
# Out:
#     product_id           product_name    brand category  cocoa_percent  \
# 0        P0001    White Chocolate 80%     Mars  Truffle             80
# 1        P0002     Dark Chocolate 70%  Cadbury  Praline             70
# 2        P0003  Truffle Chocolate 70%  Hershey  Praline             70
# 3        P0004     Milk Chocolate 50%     Mars  Praline             50
# 4        P0005    White Chocolate 70%  Ferrero    White             70
# ..         ...                    ...      ...      ...            ...
# 195      P0196    White Chocolate 60%     Mars  Praline             60
# 196      P0197  Truffle Chocolate 90%  Hershey  Truffle             90
# 197      P0198     Dark Chocolate 90%  Ferrero    White             90
# 198      P0199     Dark Chocolate 70%  Hershey    White             70
# 199      P0200     Milk Chocolate 50%  Cadbury     Milk             50
#
#      weight_g
# 0         120
# 1         100
# 2         120
# 3          80
# 4          50
# ..        ...
# ...

# %%
products=pd.read_csv("products.csv")

# %%
print(products)
# Out:
#     product_id           product_name    brand category  cocoa_percent  \
# 0        P0001    White Chocolate 80%     Mars  Truffle             80
# 1        P0002     Dark Chocolate 70%  Cadbury  Praline             70
# 2        P0003  Truffle Chocolate 70%  Hershey  Praline             70
# 3        P0004     Milk Chocolate 50%     Mars  Praline             50
# 4        P0005    White Chocolate 70%  Ferrero    White             70
# ..         ...                    ...      ...      ...            ...
# 195      P0196    White Chocolate 60%     Mars  Praline             60
# 196      P0197  Truffle Chocolate 90%  Hershey  Truffle             90
# 197      P0198     Dark Chocolate 90%  Ferrero    White             90
# 198      P0199     Dark Chocolate 70%  Hershey    White             70
# 199      P0200     Milk Chocolate 50%  Cadbury     Milk             50
#
#      weight_g
# 0         120
# 1         100
# 2         120
# 3          80
# 4          50
# ..        ...
# ...

# %% [markdown]
# # New Section

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     200 non-null    object
#  1   product_name   200 non-null    object
#  2   brand          200 non-null    object
#  3   category       200 non-null    object
#  4   cocoa_percent  200 non-null    int64
#  5   weight_g       200 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 9.5+ KB

# %%
products.describe()
# Out:
#        cocoa_percent    weight_g
# count     200.000000  200.000000
# mean       69.150000  107.500000
# std        14.623499   50.898954
# min        50.000000   50.000000
# 25%        50.000000   80.000000
# 50%        70.000000  100.000000
# 75%        80.000000  120.000000
# max        90.000000  200.000000

# %%
products.shape
# Out:
# (200, 6)

# %%
products.size
# Out:
# 1200

# %%
products.columns
# Out:
# Index(['product_id', 'product_name', 'brand', 'category', 'cocoa_percent',
#        'weight_g'],
#       dtype='object')

# %%
products.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
products.dtypes
# Out:
# product_id       object
# product_name     object
# brand            object
# category         object
# cocoa_percent     int64
# weight_g          int64
# dtype: object

# %%
products['product_name']
# Out:
# 0        White Chocolate 80%
# 1         Dark Chocolate 70%
# 2      Truffle Chocolate 70%
# 3         Milk Chocolate 50%
# 4        White Chocolate 70%
#                ...
# 195      White Chocolate 60%
# 196    Truffle Chocolate 90%
# 197       Dark Chocolate 90%
# 198       Dark Chocolate 70%
# 199       Milk Chocolate 50%
# Name: product_name, Length: 200, dtype: object

# %%
products[["product_name","brand"]]
# Out:
#               product_name    brand
# 0      White Chocolate 80%     Mars
# 1       Dark Chocolate 70%  Cadbury
# 2    Truffle Chocolate 70%  Hershey
# 3       Milk Chocolate 50%     Mars
# 4      White Chocolate 70%  Ferrero
# ..                     ...      ...
# 195    White Chocolate 60%     Mars
# 196  Truffle Chocolate 90%  Hershey
# 197     Dark Chocolate 90%  Ferrero
# 198     Dark Chocolate 70%  Hershey
# 199     Milk Chocolate 50%  Cadbury
#
# [200 rows x 2 columns]

# %% [markdown]
# Select a single row by label:

# %%
products.loc[0]
# Out:
# product_id                     P0001
# product_name     White Chocolate 80%
# brand                           Mars
# category                     Truffle
# cocoa_percent                     80
# weight_g                         120
# Name: 0, dtype: object

# %% [markdown]
# Select specific rows and columns:

# %%
products.loc[0,"brand"]
# Out:
# 'Mars'

# %%
products.loc[[0,1],'brand']
# Out:
# 0       Mars
# 1    Cadbury
# Name: brand, dtype: object

# %%
products.loc['product_name':'brand','category']
# Out:
# Series([], Name: category, dtype: object)

# %%
products.iloc[0,1]
# Out:
# 'White Chocolate 80%'

# %% [markdown]
# row labe + column name

# %%
products.at[0,'brand']
# Out:
# 'Mars'

# %%
products.iat[1,1]
# Out:
# 'Dark Chocolate 70%'

# %%
products[products['cocoa_percent']>50]
# Out:
#     product_id           product_name    brand category  cocoa_percent  \
# 0        P0001    White Chocolate 80%     Mars  Truffle             80
# 1        P0002     Dark Chocolate 70%  Cadbury  Praline             70
# 2        P0003  Truffle Chocolate 70%  Hershey  Praline             70
# 4        P0005    White Chocolate 70%  Ferrero    White             70
# 6        P0007  Praline Chocolate 70%  Cadbury  Praline             70
# ..         ...                    ...      ...      ...            ...
# 194      P0195    White Chocolate 90%  Cadbury     Dark             90
# 195      P0196    White Chocolate 60%     Mars  Praline             60
# 196      P0197  Truffle Chocolate 90%  Hershey  Truffle             90
# 197      P0198     Dark Chocolate 90%  Ferrero    White             90
# 198      P0199     Dark Chocolate 70%  Hershey    White             70
#
#      weight_g
# 0         120
# 1         100
# 2         120
# 4          50
# 6         120
# ..        ...
# ...

# %%
products.isnull()
# Out:
#      product_id  product_name  brand  category  cocoa_percent  weight_g
# 0         False         False  False     False          False     False
# 1         False         False  False     False          False     False
# 2         False         False  False     False          False     False
# 3         False         False  False     False          False     False
# 4         False         False  False     False          False     False
# ..          ...           ...    ...       ...            ...       ...
# 195       False         False  False     False          False     False
# 196       False         False  False     False          False     False
# 197       False         False  False     False          False     False
# 198       False         False  False     False          False     False
# 199       False         False  False     False          False     False
#
# [200 rows x 6 columns]

# %%
products.fillna(0)
# Out:
#     product_id           product_name    brand category  cocoa_percent  \
# 0        P0001    White Chocolate 80%     Mars  Truffle             80
# 1        P0002     Dark Chocolate 70%  Cadbury  Praline             70
# 2        P0003  Truffle Chocolate 70%  Hershey  Praline             70
# 3        P0004     Milk Chocolate 50%     Mars  Praline             50
# 4        P0005    White Chocolate 70%  Ferrero    White             70
# ..         ...                    ...      ...      ...            ...
# 195      P0196    White Chocolate 60%     Mars  Praline             60
# 196      P0197  Truffle Chocolate 90%  Hershey  Truffle             90
# 197      P0198     Dark Chocolate 90%  Ferrero    White             90
# 198      P0199     Dark Chocolate 70%  Hershey    White             70
# 199      P0200     Milk Chocolate 50%  Cadbury     Milk             50
#
#      weight_g
# 0         120
# 1         100
# 2         120
# 3          80
# 4          50
# ..        ...
# ...

# %%
products.dropna()
# Out:
#     product_id           product_name    brand category  cocoa_percent  \
# 0        P0001    White Chocolate 80%     Mars  Truffle             80
# 1        P0002     Dark Chocolate 70%  Cadbury  Praline             70
# 2        P0003  Truffle Chocolate 70%  Hershey  Praline             70
# 3        P0004     Milk Chocolate 50%     Mars  Praline             50
# 4        P0005    White Chocolate 70%  Ferrero    White             70
# ..         ...                    ...      ...      ...            ...
# 195      P0196    White Chocolate 60%     Mars  Praline             60
# 196      P0197  Truffle Chocolate 90%  Hershey  Truffle             90
# 197      P0198     Dark Chocolate 90%  Ferrero    White             90
# 198      P0199     Dark Chocolate 70%  Hershey    White             70
# 199      P0200     Milk Chocolate 50%  Cadbury     Milk             50
#
#      weight_g
# 0         120
# 1         100
# 2         120
# 3          80
# 4          50
# ..        ...
# ...

# %%
products.isnull()
# Out:
#      product_id  product_name  brand  category  cocoa_percent  weight_g
# 0         False         False  False     False          False     False
# 1         False         False  False     False          False     False
# 2         False         False  False     False          False     False
# 3         False         False  False     False          False     False
# 4         False         False  False     False          False     False
# ..          ...           ...    ...       ...            ...       ...
# 195       False         False  False     False          False     False
# 196       False         False  False     False          False     False
# 197       False         False  False     False          False     False
# 198       False         False  False     False          False     False
# 199       False         False  False     False          False     False
#
# [200 rows x 6 columns]

# %%
products.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
products.drop_duplicates()
# Out:
#     product_id           product_name    brand category  cocoa_percent  \
# 0        P0001    White Chocolate 80%     Mars  Truffle             80
# 1        P0002     Dark Chocolate 70%  Cadbury  Praline             70
# 2        P0003  Truffle Chocolate 70%  Hershey  Praline             70
# 3        P0004     Milk Chocolate 50%     Mars  Praline             50
# 4        P0005    White Chocolate 70%  Ferrero    White             70
# ..         ...                    ...      ...      ...            ...
# 195      P0196    White Chocolate 60%     Mars  Praline             60
# 196      P0197  Truffle Chocolate 90%  Hershey  Truffle             90
# 197      P0198     Dark Chocolate 90%  Ferrero    White             90
# 198      P0199     Dark Chocolate 70%  Hershey    White             70
# 199      P0200     Milk Chocolate 50%  Cadbury     Milk             50
#
#      weight_g
# 0         120
# 1         100
# 2         120
# 3          80
# 4          50
# ..        ...
# ...

# %%
products['product_id'].value_counts()
# Out:
# product_id
# P0001    1
# P0002    1
# P0003    1
# P0004    1
# P0005    1
#         ..
# P0196    1
# P0197    1
# P0198    1
# P0199    1
# P0200    1
# Name: count, Length: 200, dtype: int64

# %%
products['brand'].str.upper()
# Out:
# 0         MARS
# 1      CADBURY
# 2      HERSHEY
# 3         MARS
# 4      FERRERO
#         ...
# 195       MARS
# 196    HERSHEY
# 197    FERRERO
# 198    HERSHEY
# 199    CADBURY
# Name: brand, Length: 200, dtype: object

# %%
sales=pd.read_csv("sales.csv")

# %%
print(sales)
# Out:
#            order_id  order_date product_id store_id customer_id  quantity  \
# 0       0RD00000001  2023-01-07      P0080     S093     C040749         5
# 1       0RD00000002  2023-10-22      P0173     S065     C020161         3
# 2       0RD00000003  2023-05-07      P0115     S078     C048069         2
# 3       0RD00000004  2024-06-23      P0186     S088     C047901         2
# 4       0RD00000005  2024-09-24      P0197     S054     C033950         1
# ...             ...         ...        ...      ...         ...       ...
# 999995  0RD00999996  2023-04-15      P0103     S053     C044763         4
# 999996  0RD00999997  2023-05-26      P0094     S058     C004441         2
# 999997  0RD00999998  2023-07-05      P0097     S041     C044879         3
# 999998  0RD00999999  2024-01-03      P0090     S083     C042525         1
# 999999  0RD01000000  2024-04-10      P0175     S090     C025078         1
#
#         unit_price  discount  revenue   cost  profit
# ...

# %%
sales.isnull()
# Out:
#         order_id  order_date  product_id  store_id  customer_id  quantity  \
# 0          False       False       False     False        False     False
# 1          False       False       False     False        False     False
# 2          False       False       False     False        False     False
# 3          False       False       False     False        False     False
# 4          False       False       False     False        False     False
# ...          ...         ...         ...       ...          ...       ...
# 999995     False       False       False     False        False     False
# 999996     False       False       False     False        False     False
# 999997     False       False       False     False        False     False
# 999998     False       False       False     False        False     False
# 999999     False       False       False     False        False     False
#
#         unit_price  discount  revenue   cost  profit
# ...

# %%
sales.isnull().sum()
# Out:
# order_id       0
# order_date     0
# product_id     0
# store_id       0
# customer_id    0
# quantity       0
# unit_price     0
# discount       0
# revenue        0
# cost           0
# profit         0
# dtype: int64

# %%
sales.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Length: 1000000, dtype: bool

# %%
sales.drop_duplicates()
# Out:
#            order_id  order_date product_id store_id customer_id  quantity  \
# 0       0RD00000001  2023-01-07      P0080     S093     C040749         5
# 1       0RD00000002  2023-10-22      P0173     S065     C020161         3
# 2       0RD00000003  2023-05-07      P0115     S078     C048069         2
# 3       0RD00000004  2024-06-23      P0186     S088     C047901         2
# 4       0RD00000005  2024-09-24      P0197     S054     C033950         1
# ...             ...         ...        ...      ...         ...       ...
# 999995  0RD00999996  2023-04-15      P0103     S053     C044763         4
# 999996  0RD00999997  2023-05-26      P0094     S058     C004441         2
# 999997  0RD00999998  2023-07-05      P0097     S041     C044879         3
# 999998  0RD00999999  2024-01-03      P0090     S083     C042525         1
# 999999  0RD01000000  2024-04-10      P0175     S090     C025078         1
#
#         unit_price  discount  revenue   cost  profit
# ...

# %%
sales.groupby("discount")['unit_price'].sum()
# Out:
# discount
# 0.00    5627888.99
# 0.10    1122414.71
# 0.15    1129441.33
# 0.20    1122704.01
# Name: unit_price, dtype: float64

# %%
customers=pd.read_csv("customers.csv")

# %%
customers.groupby("age")

# %%
print(sales)
# Out:
#            order_id  order_date product_id store_id customer_id  quantity  \
# 0       0RD00000001  2023-01-07      P0080     S093     C040749         5
# 1       0RD00000002  2023-10-22      P0173     S065     C020161         3
# 2       0RD00000003  2023-05-07      P0115     S078     C048069         2
# 3       0RD00000004  2024-06-23      P0186     S088     C047901         2
# 4       0RD00000005  2024-09-24      P0197     S054     C033950         1
# ...             ...         ...        ...      ...         ...       ...
# 999995  0RD00999996  2023-04-15      P0103     S053     C044763         4
# 999996  0RD00999997  2023-05-26      P0094     S058     C004441         2
# 999997  0RD00999998  2023-07-05      P0097     S041     C044879         3
# 999998  0RD00999999  2024-01-03      P0090     S083     C042525         1
# 999999  0RD01000000  2024-04-10      P0175     S090     C025078         1
#
#         unit_price  discount  revenue   cost  profit
# ...

# %%
mcsa=pd.merge(customers,sales,on='customer_id')

# %%
print(mcsa)
# Out:
#        customer_id  age  gender  loyalty_member   join_date     order_id  \
# 0          C000001   40    Male               1  2025-05-21  0RD00007338
# 1          C000001   40    Male               1  2025-05-21  0RD00065169
# 2          C000001   40    Male               1  2025-05-21  0RD00070369
# 3          C000001   40    Male               1  2025-05-21  0RD00085016
# 4          C000001   40    Male               1  2025-05-21  0RD00169882
# ...            ...  ...     ...             ...         ...          ...
# 999995     C050000   39  Female               1  2023-12-02  0RD00805872
# 999996     C050000   39  Female               1  2023-12-02  0RD00890383
# 999997     C050000   39  Female               1  2023-12-02  0RD00940128
# 999998     C050000   39  Female               1  2023-12-02  0RD00966042
# 999999     C050000   39  Female               1  2023-12-02  0RD00989486
#
#         order_date product_id store_id  quantity  unit_price  discount  \
# ...

# %%
mcsa.groupby('age')['profit'].sum()
# Out:
# age
# 18    194390.00
# 19    202201.93
# 20    183624.93
# 21    200029.56
# 22    196535.37
# 23    198467.05
# 24    188905.10
# 25    188475.48
# 26    188689.96
# 27    185317.33
# 28    186819.42
# 29    196331.39
# 30    180226.78
# 31    191744.00
# 32    189763.18
# 33    187591.80
# 34    188960.61
# 35    199356.49
# 36    200280.91
# 37    184010.44
# 38    201219.28
# 39    191104.82
# 40    201406.33
# 41    174924.01
# 42    184995.03
# 43    193764.65
# 44    192756.90
# 45    197695.35
# 46    199357.63
# 47    195634.51
# 48    194950.32
# 49    186874.12
# 50    193392.80
# 51    182500.53
# 52    190358.14
# 53    184691.29
# 54    197649.71
# 55    185318.99
# 56    197279.58
# 57    199317.49
# 58    197018.21
# 59    185632.01
# 60    188031.22
# 61    189479.01
# 62    191229.82
# 63    209923.19
# 64    197518.14
# 65    197832.24
# 66    193099.39
# 67    193237.13
# 68    191286.39
# 69    190463.15
# 70    192901.52
# Name: profit, dtype: float64

# %%
customers.replace("Male","M")
# Out:
#       customer_id  age  gender  loyalty_member   join_date
# 0         C000001   40       M               1  2025-05-21
# 1         C000002   47       M               0  2021-12-26
# 2         C000003   58  Female               1  2022-09-13
# 3         C000004   25  Female               0  2025-02-27
# 4         C000005   43       M               0  2023-08-31
# ...           ...  ...     ...             ...         ...
# 49995     C049996   30  Female               1  2022-11-21
# 49996     C049997   24  Female               0  2022-08-30
# 49997     C049998   53       M               0  2024-09-22
# 49998     C049999   31  Female               1  2025-08-23
# 49999     C050000   39  Female               1  2023-12-02
#
# [50000 rows x 5 columns]

# %%
customers=customers['age'].astype(float)

# %%
print(customers)
# Out:
# 0        40.0
# 1        47.0
# 2        58.0
# 3        25.0
# 4        43.0
#          ...
# 49995    30.0
# 49996    24.0
# 49997    53.0
# 49998    31.0
# 49999    39.0
# Name: age, Length: 50000, dtype: float64

# %%
products['brand'].unique()
# Out:
# array(['Mars', 'Cadbury', 'Hershey', 'Ferrero', 'Godiva', 'Lindt'],
#       dtype=object)

# %%
products.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
products[products.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, brand, category, cocoa_percent, weight_g]
# Index: []
